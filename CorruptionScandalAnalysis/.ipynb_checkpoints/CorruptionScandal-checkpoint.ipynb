# %% [markdown]
# ## LAVA JATO - AN INFOGRAPHIC OF THE CORRUPTION SCANDALS IN BRAZIL

# %%
from os import listdir
from os.path import isfile, join

delacoes = ['./Delações/' + f for f in listdir('./Delações/') if isfile(join('./Delações/', f))]

print('Reading done. 10 first files:')
delacoes[:10]
# Out:
# Reading done. 10 first files:
# ['./Delações/Colaboração premiada - Alberto Youssef - Depoimento 1.pdf',
#  './Delações/Colaboração premiada - Alberto Youssef - Depoimento 10.pdf',
#  './Delações/Colaboração premiada - Alberto Youssef - Depoimento 11.pdf',
#  './Delações/Colaboração premiada - Alberto Youssef - Depoimento 12.pdf',
#  './Delações/Colaboração premiada - Alberto Youssef - Depoimento 13.pdf',
#  './Delações/Colaboração premiada - Alberto Youssef - Depoimento 14.pdf',
#  './Delações/Colaboração premiada - Alberto Youssef - Depoimento 15.pdf',
#  './Delações/Colaboração premiada - Alberto Youssef - Depoimento 16.pdf',
#  './Delações/Colaboração premiada - Alberto Youssef - Depoimento 17.pdf',
#  './Delações/Colaboração premiada - Alberto Youssef - Depoimento 18.pdf']

# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfparser import PDFPage
from pdfminer.pdfparser import *
from io import StringIO

txtDelacoes = []

def convert_pdf_to_txt(path):
    retstr = StringIO()
    rsrcmgr = PDFResourceManager()
    device = TextConverter(rsrcmgr, retstr, laparams=LAParams())
    interpreter = PDFPageInterpreter(rsrcmgr, device)

    fp = open(path, 'rb')

    parser = PDFParser(fp)
    document = PDFDocument()
    parser.set_document(document)
    document.set_parser(parser)

    for page in document.get_pages():
        interpreter.process_page(page)

    text = retstr.getvalue()

    fp.close()
    device.close()
    retstr.close()
    return text

count = 1

for delacaoPdf in delacoes:
    txtDelacoes.append(convert_pdf_to_txt(delacaoPdf))
    if count % 10 == 0:
        print(count)
    count += 1


print('Processing done. Content sample:')
print(txtDelacoes[0][:300])
# Out:
# 10
# 20
# 30
# 40
# 50
# 60
# 70
# 80
# Processing done. Content sample:
# --------------------------------~-~ -
#
# CONFIDENCIAL
# POLICIA FEDERAL
#
# SUPERINTEND~NCIA REGIONAL NO ESTAOO 00 PARANÁ
#
# TERMO DE COLABORAÇÃO N ° 01
#
# TERMO DE DECLARA Ç ÕES
#
# que presta ALBERTO YOUSSEF
#
# DRCOR - Delegacia Regional de Combate ao Crime Organizado
# DELEFIN - Delegacia de Repressão a C r

# %%
import re

def fixOcr(pattern):
    result = ""
    for c in pattern:
        result += c + "\s?"
    result = result[:-3]
        
    result = re.sub('[DO0]','[DO0]',result)
    result = re.sub('Ê','[Ê~]',result)
    result = re.sub('Á','[AÁ]',result)
    return result

def extractDelation(delationPdfText):
    if re.search('\nque presta ', delationPdfText) != None:
        delationPdfText = delationPdfText[re.search('\nque presta ',delationPdfText).span()[0]:]
        
    delationPdfText = re.sub(fixOcr('CONFIDENCIAL \nPOLICIA FEDERAL'),'',delationPdfText)
    delationPdfText = re.sub('\nSUPER\s.+','',delationPdfText)
    delationPdfText = re.sub('\n\\d{11} Pet.+','',delationPdfText)
    delationPdfText = re.sub('\n•.*','',delationPdfText)
    delationPdfText = re.sub(fixOcr('\nCONFIDENCIAL'),'',delationPdfText)
    delationPdfText = re.sub(fixOcr('\nSUPERINTENDIONCIA'),'',delationPdfText)
    delationPdfText = re.sub(fixOcr('SUPERINTENDÊNCIA REGIONAL NO ESTAOO DO PARANÁ'),'',delationPdfText)
    delationPdfText = re.sub(fixOcr('REGIONAL NO ESTAOO DO PARANÁ'),'',delationPdfText)
    delationPdfText = re.sub(fixOcr('TERMO DE COLABORAÇÃO ') + 'N[^\n]+','',delationPdfText)
    delationPdfText = re.sub(fixOcr('TERMO DE DECLARAÇÕES '),'',delationPdfText)
    delationPdfText = re.sub(fixOcr('DRCOR - Delegacia Regional de Comba') + '[tl]' + fixOcr('e ao Crime Organizado'),'',delationPdfText)
    delationPdfText = re.sub(fixOcr('TERMO DE DECLARAÇÕES'),'',delationPdfText)
    delationPdfText = re.sub(fixOcr('DELEFIN - Delegacia de Repressão a Crimes contra o Sistema Financeiro e Desvio de Verbas Públicas'),'',delationPdfText)
    delationPdfText = re.sub(fixOcr('DELEFIN - Delegacia de Repressão a Crimes contra o Sistema Financeiro e Desvio de Veribas Públicas'),'',delationPdfText)
    
    #for some reason, OCR messed up these words all around
    delationPdfText = re.sub(fixOcr('escritório'),'escritório',delationPdfText)
    delationPdfText = re.sub(fixOcr('JOSÉ'),'JOSÉ',delationPdfText)
    delationPdfText = re.sub(fixOcr('Queiroz Galvão'),'Queiroz Galvão',delationPdfText)
    delationPdfText = re.sub(fixOcr('QUEIROZ GALVÃO'),'QUEIROZ GALVÃO',delationPdfText)
    delationPdfText = re.sub(fixOcr('QUEIROZ GALVAO'),'QUEIROZ GALVÃO',delationPdfText)
    delationPdfText = re.sub('Q\s?U\s?A\s?T\s?[TI]\s?O\s?R','QUATTOR',delationPdfText)
    delationPdfText = re.sub('(\\sç|ç\\s)','ç',delationPdfText)
    delationPdfText = re.sub('(\\sÇ|Ç\\s)','Ç',delationPdfText)
    delationPdfText = re.sub('(\\sí|í\\s)','í',delationPdfText)
    delationPdfText = re.sub('(\\sÍ|Í\\s)','Í',delationPdfText)
    delationPdfText = re.sub('(\\sã|ã\\s)','ã',delationPdfText)
    delationPdfText = re.sub('(\\sÃ|Ã\\s)','Ã',delationPdfText)
    
    #Transforming names into caps
    delationPdfText = re.sub('São Paulo','SÃO PAULO',delationPdfText)
    delationPdfText = re.sub('são paulo','SÃO PAULO',delationPdfText)
    delationPdfText = re.sub('Rio de Janeiro','RIO DE JANEIRO',delationPdfText)
    delationPdfText = re.sub('Porto Alegre','PORTO ALEGRE',delationPdfText)
    delationPdfText = re.sub('São Luís','SÃO LUÍS',delationPdfText)
    
    #Making useless words lower-caps
    delationPdfText = re.sub('\\bQUE\\b','que',delationPdfText)
    
    if re.search('\nDECLARANTE:', delationPdfText) != None:
        delationPdfText = delationPdfText[:re.search('\nDECLARANTE:',delationPdfText).span()[0]]
    
    delationPdfText = re.sub('\n+','',delationPdfText)
    return delationPdfText

txtDelacaoPaths = []

for delacaoNum in range(len(txtDelacoes)):
    result = extractDelation(txtDelacoes[delacaoNum])
    txtDelacaoPath = 'DelaçõesTxt' + delacoes[delacaoNum][10:-3] + 'txt'
    txtDelacaoPaths.append(txtDelacaoPath)
    outputFile = open(txtDelacaoPath, 'w')
    outputFile.write(result)
    outputFile.close()

print('Extraction done and saved. Content sample:')
print(result[:500])
# Out:
# Extraction done and saved. Content sample:
# • TERMO DE _'o '>.' M IN ISTÍ !R IO PúBuco FEDERAL P rocu rado r ia -Ge ra l da· RepúbBca "'LLH..KR'L,"J"'~ COMPLEMENTAR N° 09 ALBERTO YOUSSEF Aos onze dias do mês de fevereiro de 2015, na Superintendência da Polícia Federal em Curitiba, presentes os Procuradores da República Andrey Borges de Mendonça e Bruno Calabrich e o Promotor de Justiça Wilton Queiroz de Lima, integrantes do Grupo de Trabalho instituído pela Procurador-Geral da República através da Portaria PGR/MPU nO 3, de 19/01/2015, e a

# %%
words = []
capsNamesOccurences = {}

count = 0

for txtDelacaoPath in txtDelacaoPaths:    
    txtDelacaoFile = open(txtDelacaoPath, 'r')
    txtDelacao = txtDelacaoFile.read()

    txtDelacaoFile.close()
    capsNames = re.findall('((?:[A-Z\\u00C3-\\u00C4Ç]+[\s\)"\'\.\\/,;])+)', txtDelacao) 
    capsNames = [str.lower(name[:-1]) for name in capsNames]
    
    capsNames = [capsName for capsName in capsNames if len(capsName) > 2]
    
    for capsName in capsNames:
        if(capsName in capsNamesOccurences):
            capsNamesOccurences[capsName] += 1
        else:
            capsNamesOccurences[capsName] = 1
            
    words.extend(capsNames)

    for name in capsNames:
        try:
            txtDelacao = re.sub(str.upper(name), '', txtDelacao)
        except:
            print(name)

    splitted = str.split(txtDelacao, ' ')
    words.extend(splitted)

wordCount = {}

for word in words:    
    if(re.search('\d', word) == None and len(word) > 1) and re.search('\w{2}', word) != None:
        fixedWord = str.lower(re.sub('[,;\.\n_"\(\)\\\'-]','',word))
        if(fixedWord in wordCount):
            wordCount[fixedWord] += 1
        else:
            wordCount[fixedWord] = 1

# DISCLAIMER:
# If you speak Portuguese, you might notice several of these words are not really useless.
# I've added them to this list so they don't appear in the count. 
# Some of them appear several times in the documents on parts not related to what the process is about.
# Some of them are on headers and footers of the documents
# Some of them are in fact in the process, but don't really tell anything about the process.
# I've questioned myself if adding the ones in this last case would be 'manipulating' the word cloud so
# that it would look like what I thought it should.
# My conclusion was that these words, even though they're legitimate, only *help* to tell the story.
# They are not the story.
# If you disagree with this approach, e-mail me at marcelo.f.ramires@gmail.com
mostCommonUselessWords = ['-', '', 'de','era', 'eram','junto','a', 'é','•', 'feito','que','diz','anteriormente','serem',
                          'fazer','tendo','quem','dos', 'segundo','ter','sendo','art.', 'conforme','qual','afirma','o', 
                          'pelas','podendo','quais','do', 'acerca','da', 'fim','no', 'em', 'se', 'como', 'um', 'uma', 
                          'os', 'as', 'para', 'e', 'por', 'na', 'com', 'Dos', 'ou', 'das', 'são', 'ao', 'entre', 'mais', 
                          'nos', 'ser', 'sua', 'mas', 'tem', 'também', 'pela', 'sobre', 'seu', 'pelo', 'pode', 'termos',
                          'assim', 'esta', 'nas', 'já', 'aos', 'questão', 'diferentes', 'termo', 'in', 'mesmo', 'século',
                          'outro', 'este', 'isso', 'pois', 'há', 'isto', 'lugar', 'the', 'esse', 'outros', 'sem', 'uso', 
                          'essa', 'lá', 'foi', 'ainda', 'ele', 'não', 'só', 'realização','determinada','algum','seria',
                          'assevera','pessoa','teve','próprio','ate','inicialmente','sempre','vezes','havia','pet','passou',
                          'presente','algumas','\x0c', 'período','recorda-se','antes','nota','prévio','seja','sido',
                          'todavia','feitos','inclusive','meio','teve','sido','declarante', 'pediu', 'disse', 'certeza',
                          'angulo', 'deste', 'questionado', 'ia', 'cpf', 'rg', 'rua', 'confirmar', 'três', 'entender',
                          'partiu', 'salvo', 'todos', 'registro', '\x0cpgr', 'endereço', 'confirma', 'engano', 'serão'
                          'presentes', 'república', 'nesse', 'razão', 'presença', 'duas', 'art', 'iv', 'complementar',
                          'to', 'xv', 'geral', 'devidamente', 'federal', 'lei', 'colaboração', 'ato', 'demais', 'caso',
                          'polícia', 'sabe', 'defensor', 'ciente', 'nome', 'penais', 'ora', 'público', 'escrito', 'dizer',
                          'serão', 'parte', 'estar', 'final', 'recorda', 'fosse', 'foram', 'todas', 'samsung', 'nada',
                          'pelos', 'além', 'lhe', 'estão', 'fato', 'verdade', 'filho', 'direito', 'legal', 'comissão',
                          'casado', 'oitiva', 'cautelas', 'assinadas', 'lacrados', 'digital', 'firmando', 'autorizam'
                          'hd', 'superintendência', 'audiovisual', 'acredita', 'forma', 'cientes', 'preservação'
                          'recursos', 'expressamente', 'diretoria', 'época', 'mídia', 'po', 'encerrado', 'lido', 'te' 
                          'nesta', 'havendo', 'lacrado', 'dentre', 'tais', 'vai', 'determinouse', 'achado', 'nem',
                          'entrega', 'número', 'total', 'divisão', 'ano', 'perante', 'sob', 'eles', 'tal', 'notas'
                          'teria', 'poder', 'cento', 'anexo', 'houve', 'estando', 'social', 'padrão', 'penal', 'declara',
                          'is', 'cerca', 'estrutura', 'prévia', 'notadamente', 'constante', 'decorrentes', 'mês', 'bem'
                          'te', 'vi', 'daquele', 'pretende', 'identificação', 'efetiva', 'visual', 'seguintes', 'le', 
                          'levado', 'ficará', 'tracy joseph reinaldetdos santos', 'ra', 'lo', 'fez', 'ju', 'ta']

for uselessWord in mostCommonUselessWords:
    wordCount.pop(uselessWord, None)

#Since we're aiming for names rather than normal substantives, we multiply the names occurences
for kvp in wordCount:
    if kvp in capsNamesOccurences:
        wordCount[kvp] = wordCount[kvp] * 2
    
sortedWordCount = sorted(wordCount.items(), key=lambda word: word[1])
sortedWordCount.reverse()
sortedWordCount[:100]
# Out:
# [('paulo roberto costa', 478),
#  ('alberto youssef', 450),
#  ('youssef', 370),
#  ('valores', 342),
#  ('advogado', 332),
#  ('empresa', 265),
#  ('petrobras', 248),
#  ('partido', 234),
#  ('criminosa', 223),
#  ('organização', 218),
#  ('julio camargo', 210),
#  ('janene', 192),
#  ('oab/pr', 192),
#  ('valor', 185),
#  ('sigilo', 175),
#  ('procurador', 168),
#  ('infrações', 167),
#  ('empresas', 162),
#  ('ministério', 161),
#  ('informações', 150),
#  ('relação', 140),
#  ('conta', 132),
#  ('dinheiro', 128),
#  ('jose janene', 128),
#  ('fundo', 124),
#  ('progressista', 122),
#  ('reais', 120),
#  ('lima', 120),
#  ('contratos', 118),
#  ('coautores', 113),
#  ('pgr', 112),
#  ('praticadas', 112),
#  ('contato', 112),
#  ('homologação', 111),
#  ('atendendo', 111),
#  ('colaborador', 108),
#  ('gfd', 104),
#  ('milhões', 103),
#  ('queiroz galvão', 102),
#  ('escritório', 102),
#  ('tracy joseph reinaldet dos santos', 102),
#  ('entregues', 101),
#  ('espécie', 101),
# ...

# %%
result = ''

for kvp in sortedWordCount[:100]:
    for ct in range(int(kvp[1] / 10)):
        result += kvp[0].replace(' ', '-') + " "
        
# This is what we insert into a wordcloud generating tool to generate a wordcloud
print(result)
# Out:
# valores valores valores valores valores valores valores valores valores valores valores valores valores valores valores valores valores valores valores valores valores valores valores valores valores valores valores valores valores valores valores valores valores valores empresa empresa empresa empresa empresa empresa empresa empresa empresa empresa empresa empresa empresa empresa empresa empresa empresa empresa empresa empresa empresa empresa empresa empresa empresa empresa paulo-roberto-costa paulo-roberto-costa paulo-roberto-costa paulo-roberto-costa paulo-roberto-costa paulo-roberto-costa paulo-roberto-costa paulo-roberto-costa paulo-roberto-costa paulo-roberto-costa paulo-roberto-costa paulo-roberto-costa paulo-roberto-costa paulo-roberto-costa paulo-roberto-costa paulo-roberto-costa paulo-roberto-costa paulo-roberto-costa paulo-roberto-costa paulo-roberto-costa paulo-roberto-costa paulo-roberto-costa paulo-roberto-costa alberto-youssef alberto-youssef alberto-youssef alberto-yo
# ...
